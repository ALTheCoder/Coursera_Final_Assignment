# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:589761d0-551c-4501-8ced-428922c310c3.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:66d16e42-2b4f-48bc-a353-0b49708393b9.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ![4-dslanguages.png](attachment:c89b4d77-a0b1-4e9d-8bc0-7a89b790dc50.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. PyTorch
# 2. Keras
# 3. TensorFlow

# %% [markdown]
# ![5-dslibraries.png](attachment:4f17ceb0-03b8-47df-86ab-004770a30595.png)

# %% [markdown]
# ### Data Science Tools
# 1. RStudio
# 2. Apache Hadoop
# 3. Jupyter

# %% [markdown]
# ![6-dstools.png](attachment:f4b79ef0-5d10-45a3-b53c-a52350b11450.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:475c2623-5dcb-442b-b92e-36f26373221d.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
print((3*4)+5)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:f1d9d397-519a-460f-afaa-3c271cef93f5.png)

# %%
# This will convert 200 minutes to hours by diving by 60
print(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:7cdf1ad8-eb40-4532-b1e7-c5491c6571c0.png)

# %% [markdown]
# Objectives:
# - List popular languages for Data Science
# - List popular tools for Data Science
# - List popular libraries for Data Science

# %% [markdown]
# ![10-objectives.png](attachment:a419de8c-5755-4eee-9990-4bfe2e8b3436.png)

# %% [markdown]
# ## Author
# AL

# %% [markdown]
# ![11-authordetails.png](attachment:e7f5a6be-11dc-402a-8571-097ee6649cd2.png)
